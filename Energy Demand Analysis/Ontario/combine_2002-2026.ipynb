# %%
import pandas as pd
import os
from pathlib import Path
import matplotlib.pyplot as plt

yearly_folder = 'data/yearly_demand_2002-2026/'

csv_files = sorted(Path(yearly_folder).glob('PUB_Demand_*.csv'))
print(f"Found {len(csv_files)} CSV files:")
# Out:
# Found 25 CSV files:

# %%
dfs = []
total_rows = 0

for file in csv_files:
    df = pd.read_csv(file, skiprows=3) 
    dfs.append(df)
    rows = len(df)
    total_rows += rows
    print(f"Loaded {file.name:25} | Shape: {df.shape} | Rows: {rows}")

print(f"\n{'='*60}")
print(f"Total rows from all files: {total_rows}")
# Out:
# Loaded PUB_Demand_2002.csv       | Shape: (5880, 4) | Rows: 5880
# Loaded PUB_Demand_2003.csv       | Shape: (8760, 4) | Rows: 8760
# Loaded PUB_Demand_2004.csv       | Shape: (8784, 4) | Rows: 8784
# Loaded PUB_Demand_2005.csv       | Shape: (8760, 4) | Rows: 8760
# Loaded PUB_Demand_2006.csv       | Shape: (8760, 4) | Rows: 8760
# Loaded PUB_Demand_2007.csv       | Shape: (8760, 4) | Rows: 8760
# Loaded PUB_Demand_2008.csv       | Shape: (8784, 4) | Rows: 8784
# Loaded PUB_Demand_2009.csv       | Shape: (8760, 4) | Rows: 8760
# Loaded PUB_Demand_2010.csv       | Shape: (8760, 4) | Rows: 8760
# Loaded PUB_Demand_2011.csv       | Shape: (8760, 4) | Rows: 8760
# Loaded PUB_Demand_2012.csv       | Shape: (8784, 4) | Rows: 8784
# Loaded PUB_Demand_2013.csv       | Shape: (8760, 4) | Rows: 8760
# Loaded PUB_Demand_2014.csv       | Shape: (8760, 4) | Rows: 8760
# Loaded PUB_Demand_2015.csv       | Shape: (8760, 4) | Rows: 8760
# Loaded PUB_Demand_2016.csv       | Shape: (8784, 4) | Rows: 8784
# Loaded PUB_Demand_2017.csv       | Shape: (8760, 4) | Rows: 8760
# Loaded PUB_Demand_2018.csv       | Shape: (8760, 4) | Rows: 8760
# Loaded PUB_Demand_2019.csv       | Shape: (8760, 4) | Rows: 8760
# Loaded PUB_Demand_2020.csv       | Shape: (8784, 4) | Rows: 8784
# Loaded PUB_Demand_2021.csv       | Shape: (8760, 4) | Rows: 8760
# Loaded PUB_Demand_2022.csv       | Shape: (8760, 4) | Rows: 8760
# Loaded PUB_Demand_2023.csv       | Shape: (8760, 4) | Rows: 8760
# Loaded PUB_Demand_2024.csv       | Shape: (8784, 4) | Rows: 8784
# Loaded PUB_Demand_2025.csv       | Shape: (8759, 4) | Rows: 8759
# Loaded PUB_Demand_2026.csv       | Shape: (3169, 4) | Rows: 3169
#
# ============================================================
# Total rows from all files: 210672

# %%
combined_df = pd.concat(dfs, ignore_index=True)
print(combined_df.shape)
print(combined_df.head())
print(combined_df.dtypes)
print(combined_df.tail())
# Out:
# (210672, 4)
#          Date  Hour  Market Demand  Ontario Demand
# 0  2002-05-01     1          14141           14137
# 1  2002-05-01     2          13876           13872
# 2  2002-05-01     3          13974           13820
# 3  2002-05-01     4          13898           13744
# 4  2002-05-01     5          14378           14224
# Date              object
# Hour               int64
# Market Demand      int64
# Ontario Demand     int64
# dtype: object
#               Date  Hour  Market Demand  Ontario Demand
# 210667  2026-05-12    21          18605           16121
# 210668  2026-05-12    22          18018           14880
# 210669  2026-05-12    23          17714           14193
# 210670  2026-05-12    24          17366           13581
# 210671  2026-05-13     1          17787           13577

# %%
# Save combined dataframe to CSV
output_file = './data/Combined_Yearly_Demand_2002-2026.csv'
combined_df.to_csv(output_file, index=False)
print(f"✓ Saved to: {output_file}")
print(f"Total rows saved: {len(combined_df)}")
# Out:
# ✓ Saved to: ./data/Combined_Yearly_Demand_2002-2026.csv
# Total rows saved: 210672

# %%
# Verify combined file
df_check = pd.read_csv('./data/Combined_Yearly_Demand_2002-2026.csv')

print(f"Final file total rows: {len(df_check)}")
print(f"Columns: {df_check.columns.tolist()}")
print(f"\nFirst row:\n{df_check.head(1)}")
print(f"\nLast row:\n{df_check.tail(1)}")
print(f"\nMissing values:")
print(df_check.isnull().sum())
# Out:
# Final file total rows: 210672
# Columns: ['Date', 'Hour', 'Market Demand', 'Ontario Demand']
#
# First row:
#          Date  Hour  Market Demand  Ontario Demand
# 0  2002-05-01     1          14141           14137
#
# Last row:
#               Date  Hour  Market Demand  Ontario Demand
# 210671  2026-05-13     1          17787           13577
#
# Missing values: 0
